# %%
#I will be online from 22 september to 02 october => teams or videos
#Thursday 29/09 => 9am from 11:59 am on teams

# %% [markdown]
# # Creating a DataFrame

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# ## Using a dictionary

# %%
# Data :
# Brand : 'Coca', 'pepsi', 'Sprite', 'water'
# Taste : 5, 6, 9, 8
# Sugar content : 'high', 'high', 'high', 'low'
# YOUR TURN : Create a dataframe from the dictionnary (10 minutes) => 16:22
df = pd.DataFrame({'brand' : ['Coca', 'pepsi', 'Sprite', 'water'], 
                   'taste' : [5, 6, 9, 8],
                  'Sugar_content' : ['high', 'high', 'high', 'low']})

# %%
print(df)
# Out:
#     brand  taste Sugar_content
# 0    Coca      5          high
# 1   pepsi      6          high
# 2  Sprite      9          high
# 3   water      8           low

# %%
# Take csv data to dictionary and create dataframe
import csv
with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_3\Apple_price_csv.csv", 'r') as file:
    csvfile = csv.DictReader(file)
    df = pd.DataFrame(csvfile)
    
print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1     2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2     2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3     2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4     2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...          ...         ...         ...         ...         ...         ...
# 1758  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume
# 0     414406400
# 1     387098400
# 2     338464400
# 3     212657600
# 4     224917200
# ...         ...
# 1758   62290100
# 1759   70211500
# 1760   69026800
# 1761   54147100
# 1762   53766800
#
# [1763 rows x 7 columns]

# %% [markdown]
# ## Using a list

# %%
# Data :
# Brand : 'Coca', 'pepsi', 'Sprite', 'water'
#Taste : 5, 6, 9, 8
#Sgar content : 'high', 'high', 'high', 'low'
#YOUR TURN : 
#Create a dtaframe from the lists (10 minutes) => 16.35
brand = ['Coca', 'pepsi', 'Sprite', 'water']
taste = [5, 6, 9, 8]
sugar_content = ['high', 'high', 'high', 'low']  
df = pd.DataFrame([brand, taste, sugar_content] )
print(df)
# Out:
#       0      1       2      3
# 0  Coca  pepsi  Sprite  water
# 1     5      6       9      8
# 2  high   high    high    low

# %%
#The zip function
a = [1, 2, 3]
b = ['a', 'b', 'c']
list0 = list(zip(a, b))
df = pd.DataFrame(list0)
print(df)
# Out:
#    0  1
# 0  1  a
# 1  2  b
# 2  3  c

# %%
#YOUR TURN
# Come back to your previous dataframe and use the zip function (5 minutes) => 16:42
df = pd.DataFrame(list(zip(brand, taste, sugar_content)), columns = ['brand', 'taste', 'sugar_content'])
print(df)
print(list(zip(brand, taste, sugar_content)))
# Out:
#     brand  taste sugar_content
# 0    Coca      5          high
# 1   pepsi      6          high
# 2  Sprite      9          high
# 3   water      8           low
# [('Coca', 5, 'high'), ('pepsi', 6, 'high'), ('Sprite', 9, 'high'), ('water', 8, 'low')]

# %%
#With the csv file (easier)
import csv
with open(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_1\Apple_price_csv.csv", 'r') as file:
    csvfile = csv.reader(file)
    name_column = csvfile.__next__()
    df = pd.DataFrame(csvfile, columns = name_column)
    
print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1     2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2     2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3     2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4     2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...          ...         ...         ...         ...         ...         ...
# 1758  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume
# 0     414406400
# 1     387098400
# 2     338464400
# 3     212657600
# 4     224917200
# ...         ...
# 1758   62290100
# 1759   70211500
# 1760   69026800
# 1761   54147100
# 1762   53766800
#
# [1763 rows x 7 columns]

# %% [markdown]
# ## Using read_csv method

# %%
#create dataframe from read_csv method
df = pd.read_csv(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_1\Apple_price_csv.csv")
print(df)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1     2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2     2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3     2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4     2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...          ...         ...         ...         ...         ...         ...
# 1758  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume
# 0     414406400
# 1     387098400
# 2     338464400
# 3     212657600
# 4     224917200
# ...         ...
# 1758   62290100
# 1759   70211500
# 1760   69026800
# 1761   54147100
# 1762   53766800
#
# [1763 rows x 7 columns]

# %%
# with the date in datetime object
df = pd.read_csv(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_1\Apple_price_csv.csv",
                parse_dates = ['Date'])

print(type(df['Date'][0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# # Modify the dataframe

# %%
# Change the column names (2 methods)
df.columns =['Date', 'Open_price', 'High_price', 'Low', 'Close', 'Adj Close', 'Volume']
df = df.rename(columns = {'Date' : 'Date_and_time'})
print(df)
# Out:
#      Date_and_time  Open_price  High_price         Low       Close  \
# 0       2015-08-25   27.777500   27.777500   25.875000   25.934999
# 1       2015-08-26   26.772499   27.472500   26.262501   27.422501
# 2       2015-08-27   28.057501   28.309999   27.504999   28.230000
# 3       2015-08-28   28.042500   28.327499   27.885000   28.322500
# 4       2015-08-31   28.007500   28.632500   28.000000   28.190001
# ...            ...         ...         ...         ...         ...
# 1758    2022-08-18  173.750000  174.899994  173.119995  174.149994
# 1759    2022-08-19  173.029999  173.740005  171.309998  171.520004
# 1760    2022-08-22  169.690002  169.860001  167.139999  167.570007
# 1761    2022-08-23  167.080002  168.710007  166.649994  167.229996
# 1762    2022-08-24  167.320007  168.110001  166.250000  167.529999
#
#        Adj Close     Volume
# 0      23.681032  414406400
# 1      25.039267  387098400
# 2      25.776581  338464400
# 3      25.861042  212657600
# 4      25.740063  224917200
# ...          ...        ...
# 1758  174.149994   62290100
# 1759  171.520004   70211500
# 1760  167.570007   69026800
# 1761  167.229996   54147100
# 1762  167.529999   53766800
#
# [1763 rows x 7 columns]

# %%
#sort values
df = df.sort_values('Open_price')
print(df)
# Out:
#      Date_and_time  Open_price  High_price         Low       Close  \
# 181     2016-05-13   22.500000   22.917500   22.500000   22.629999
# 182     2016-05-16   23.097500   23.597500   22.912500   23.469999
# 180     2016-05-12   23.180000   23.195000   22.367500   22.584999
# 212     2016-06-28   23.225000   23.415001   23.035000   23.397499
# 210     2016-06-24   23.227501   23.665001   23.162500   23.350000
# ...            ...         ...         ...         ...         ...
# 1599    2021-12-30  179.470001  180.570007  178.089996  178.199997
# 1603    2022-01-05  179.610001  180.169998  174.639999  174.919998
# 1597    2021-12-28  180.160004  181.330002  178.529999  179.289993
# 1587    2021-12-13  181.119995  182.130005  175.529999  175.740005
# 1602    2022-01-04  182.630005  182.940002  179.119995  179.699997
#
#        Adj Close     Volume
# 181    20.991350  177571200
# 182    21.770531  245039200
# 180    20.949606  305258800
# 212    21.703278  161779600
# 210    21.659220  301245600
# ...          ...        ...
# 1599  177.465637   59773000
# 1603  174.199142   94537600
# 1597  178.551132   79144300
# 1587  175.015778  153237000
# 1602  178.959457   99310400
#
# [1763 rows x 7 columns]

# %%
# Reset index of dataframe
df = df.reset_index(drop = True)
print(df)
# Out:
#      Date_and_time  Open_price  High_price         Low       Close  \
# 0       2016-05-13   22.500000   22.917500   22.500000   22.629999
# 1       2016-05-16   23.097500   23.597500   22.912500   23.469999
# 2       2016-05-12   23.180000   23.195000   22.367500   22.584999
# 3       2016-06-28   23.225000   23.415001   23.035000   23.397499
# 4       2016-06-24   23.227501   23.665001   23.162500   23.350000
# ...            ...         ...         ...         ...         ...
# 1758    2021-12-30  179.470001  180.570007  178.089996  178.199997
# 1759    2022-01-05  179.610001  180.169998  174.639999  174.919998
# 1760    2021-12-28  180.160004  181.330002  178.529999  179.289993
# 1761    2021-12-13  181.119995  182.130005  175.529999  175.740005
# 1762    2022-01-04  182.630005  182.940002  179.119995  179.699997
#
#        Adj Close     Volume
# 0      20.991350  177571200
# 1      21.770531  245039200
# 2      20.949606  305258800
# 3      21.703278  161779600
# 4      21.659220  301245600
# ...          ...        ...
# 1758  177.465637   59773000
# 1759  174.199142   94537600
# 1760  178.551132   79144300
# 1761  175.015778  153237000
# 1762  178.959457   99310400
#
# [1763 rows x 7 columns]

# %%
#Use your own index: (set_index function)
df = df.sort_values('Date_and_time')
df = df.set_index(['Date_and_time'])
print(df)
# Out:
#                Open_price  High_price         Low       Close   Adj Close  \
# Date_and_time
# 2015-08-25      27.777500   27.777500   25.875000   25.934999   23.681032
# 2015-08-26      26.772499   27.472500   26.262501   27.422501   25.039267
# 2015-08-27      28.057501   28.309999   27.504999   28.230000   25.776581
# 2015-08-28      28.042500   28.327499   27.885000   28.322500   25.861042
# 2015-08-31      28.007500   28.632500   28.000000   28.190001   25.740063
# ...                   ...         ...         ...         ...         ...
# 2022-08-18     173.750000  174.899994  173.119995  174.149994  174.149994
# 2022-08-19     173.029999  173.740005  171.309998  171.520004  171.520004
# 2022-08-22     169.690002  169.860001  167.139999  167.570007  167.570007
# 2022-08-23     167.080002  168.710007  166.649994  167.229996  167.229996
# 2022-08-24     167.320007  168.110001  166.250000  167.529999  167.529999
#
#                   Volume
# Date_and_time
# 2015-08-25     414406400
# 2015-08-26     387098400
# 2015-08-27     338464400
# 2015-08-28     212657600
# 2015-08-31     224917200
# ...                  ...
# 2022-08-18      62290100
# 2022-08-19      70211500
# 2022-08-22      69026800
# 2022-08-23      54147100
# 2022-08-24      53766800
#
# [1763 rows x 6 columns]

# %%
# use several indexes

df = df.sort_values('Date_and_time')
df = df.set_index(['Date_and_time', 'Open_price'])
print(df)
# Out:
#                           High_price         Low       Close   Adj Close  \
# Date_and_time Open_price
# 2015-08-25    27.777500    27.777500   25.875000   25.934999   23.681032
# 2015-08-26    26.772499    27.472500   26.262501   27.422501   25.039267
# 2015-08-27    28.057501    28.309999   27.504999   28.230000   25.776581
# 2015-08-28    28.042500    28.327499   27.885000   28.322500   25.861042
# 2015-08-31    28.007500    28.632500   28.000000   28.190001   25.740063
# ...                              ...         ...         ...         ...
# 2022-08-18    173.750000  174.899994  173.119995  174.149994  174.149994
# 2022-08-19    173.029999  173.740005  171.309998  171.520004  171.520004
# 2022-08-22    169.690002  169.860001  167.139999  167.570007  167.570007
# 2022-08-23    167.080002  168.710007  166.649994  167.229996  167.229996
# 2022-08-24    167.320007  168.110001  166.250000  167.529999  167.529999
#
#                              Volume
# Date_and_time Open_price
# 2015-08-25    27.777500   414406400
# 2015-08-26    26.772499   387098400
# 2015-08-27    28.057501   338464400
# 2015-08-28    28.042500   212657600
# 2015-08-31    28.007500   224917200
# ...                             ...
# 2022-08-18    173.750000   62290100
# 2022-08-19    173.029999   70211500
# 2022-08-22    169.690002   69026800
# 2022-08-23    167.080002   54147100
# 2022-08-24    167.320007   53766800
#
# [1763 rows x 5 columns]

# %%
#Your TURN
#Use your csv data to get your df and put dates as index (10 minutes) 17:05
# with the date in datetime object
df = pd.read_csv(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_1\Apple_price_csv.csv",
                parse_dates = ['Date'])
df = df.set_index(['Date'])
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...                ...         ...         ...         ...         ...
# 2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#                Volume
# Date
# 2015-08-25  414406400
# 2015-08-26  387098400
# 2015-08-27  338464400
# 2015-08-28  212657600
# 2015-08-31  224917200
# ...               ...
# 2022-08-18   62290100
# 2022-08-19   70211500
# 2022-08-22   69026800
# 2022-08-23   54147100
# 2022-08-24   53766800
#
# [1763 rows x 6 columns]

# %%
# Why indexes and not columns (use %timeit function)
# %timeit print('a')
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# 103 µs ± 5.28 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1    2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2    2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3    2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4    2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...         ...         ...         ...         ...         ...         ...
# 1758 2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759 2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760 2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761 2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762 2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume
# 0     414406400
# 1     387098400
# 2     338464400
# 3     212657600
# 4     224917200
# ...         ...
# 1758   62290100
# 1759   70211500
# 1760   69026800
# 1761   54147100
# 1762   53766800
#
# [1763 rows x 7 columns]

# %%
#display columns of dataframe (2 methods)
# %timeit df[df['Open'] == 26.772499]
# Out:
# 521 µs ± 18.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit df.loc[1]
# Out:
# 210 µs ± 3.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#Adding a new columns to your DataFrame
df['Name'] = ['Gaétan' for i in range(0,1763)]
df['Surname'] = 'Chardon'
print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1    2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2    2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3    2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4    2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...         ...         ...         ...         ...         ...         ...
# 1758 2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759 2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760 2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761 2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762 2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume    Name  Surname
# 0     414406400  Gaétan  Chardon
# 1     387098400  Gaétan  Chardon
# 2     338464400  Gaétan  Chardon
# 3     212657600  Gaétan  Chardon
# 4     224917200  Gaétan  Chardon
# ...         ...     ...      ...
# 1758   62290100  Gaétan  Chardon
# 1759   70211500  Gaétan  Chardon
# 1760   69026800  Gaétan  Chardon
# 1761   54147100  Gaétan  Chardon
# 1762   53766800  Gaétan  Chardon
#
# [1763 rows x 9 columns]

# %%
# Apply a function to your dataframe
df['double_open'] = df['Open'] *2
def my_function(x):
    return int(x**2)
df['square_open'] = df['Open'].apply(my_function)
print(df)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1    2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2    2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3    2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4    2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...         ...         ...         ...         ...         ...         ...
# 1758 2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759 2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760 2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761 2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762 2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume    Name  Surname  double_open  square_open
# 0     414406400  Gaétan  Chardon    55.555000          771
# 1     387098400  Gaétan  Chardon    53.544998          716
# 2     338464400  Gaétan  Chardon    56.115002          787
# 3     212657600  Gaétan  Chardon    56.085000          786
# 4     224917200  Gaétan  Chardon    56.015000          784
# ...         ...     ...      ...          ...          ...
# 1758   62290100  Gaétan  Chardon   347.500000        30189
# 1759   70211500  Gaétan  Chardon   346.059998        29939
# 1760   69026800  Gaétan  Chardon   339.380004        28794
# 1761   54147100  Gaétan  Chardon   334.160004        27915
# 1762   53766800  Gaétan  Chardon   334.640014        27995
#
# [1763 rows x 11 columns]

# %%
# iterate on a Dataframe
for index, items in df.iterrows():
    print(items)
# Out:
# Date           2015-08-25 00:00:00
# Open                       27.7775
# High                       27.7775
# Low                         25.875
# Close                    25.934999
# Adj Close                23.681032
# Volume                   414406400
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.555
# square_open                    771
# Name: 0, dtype: object
# Date           2015-08-26 00:00:00
# Open                     26.772499
# High                       27.4725
# Low                      26.262501
# Close                    27.422501
# Adj Close                25.039267
# Volume                   387098400
# Name                        Gaétan
# Surname                    Chardon
# double_open              53.544998
# square_open                    716
# Name: 1, dtype: object
# Date           2015-08-27 00:00:00
# Open                     28.057501
# High                     28.309999
# Low                      27.504999
# Close                        28.23
# Adj Close                25.776581
# Volume                   338464400
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.115002
# square_open                    787
# Name: 2, dtype: object
# Date           2015-08-28 00:00:00
# Open                       28.0425
# High                     28.327499
# Low                         27.885
# Close                      28.3225
# Adj Close                25.861042
# Volume                   212657600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.085
# square_open                    786
# Name: 3, dtype: object
# Date           2015-08-31 00:00:00
# Open                       28.0075
# High                       28.6325
# Low                           28.0
# Close                    28.190001
# Adj Close                25.740063
# Volume                   224917200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.015
# square_open                    784
# Name: 4, dtype: object
# Date           2015-09-01 00:00:00
# Open                       27.5375
# High                     27.969999
# Low                          26.84
# Close                        26.93
# Adj Close                24.589561
# Volume                   307383600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.075
# square_open                    758
# Name: 5, dtype: object
# Date           2015-09-02 00:00:00
# Open                     27.557501
# High                     28.084999
# Low                      27.282499
# Close                    28.084999
# Adj Close                25.644186
# Volume                   247555200
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.115002
# square_open                    759
# Name: 6, dtype: object
# Date           2015-09-03 00:00:00
# Open                     28.122499
# High                        28.195
# Low                          27.51
# Close                    27.592501
# Adj Close                25.194485
# Volume                   212935600
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.244998
# square_open                    790
# Name: 7, dtype: object
# Date           2015-09-04 00:00:00
# Open                       27.2425
# High                     27.612499
# Low                      27.127501
# Close                    27.317499
# Adj Close                24.943384
# Volume                   199985200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 54.485
# square_open                    742
# Name: 8, dtype: object
# Date           2015-09-08 00:00:00
# Open                       27.9375
# High                     28.139999
# Low                          27.58
# Close                    28.077499
# Adj Close                25.637335
# Volume                   219374400
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.875
# square_open                    780
# Name: 9, dtype: object
# Date           2015-09-09 00:00:00
# Open                     28.440001
# High                     28.504999
# Low                      27.442499
# Close                      27.5375
# Adj Close                25.144264
# Volume                   340043200
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.880002
# square_open                    808
# Name: 10, dtype: object
# Date           2015-09-10 00:00:00
# Open                     27.567499
# High                         28.32
# Low                         27.475
# Close                      28.1425
# Adj Close                25.696684
# Volume                   251571200
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.134998
# square_open                    759
# Name: 11, dtype: object
# Date           2015-09-11 00:00:00
# Open                       27.9475
# High                       28.5525
# Low                      27.940001
# Close                      28.5525
# Adj Close                26.071056
# Volume                   199662000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.895
# square_open                    781
# Name: 12, dtype: object
# Date           2015-09-14 00:00:00
# Open                        29.145
# High                       29.2225
# Low                         28.715
# Close                    28.827499
# Adj Close                26.322155
# Volume                   233453600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  58.29
# square_open                    849
# Name: 13, dtype: object
# Date           2015-09-15 00:00:00
# Open                       28.9825
# High                       29.1325
# Low                         28.605
# Close                        29.07
# Adj Close                26.543575
# Volume                   173364800
# Name                        Gaétan
# Surname                    Chardon
# double_open                 57.965
# square_open                    839
# Name: 14, dtype: object
# Date           2015-09-16 00:00:00
# Open                       29.0625
# High                        29.135
# Low                      28.860001
# Close                    29.102501
# Adj Close                26.573254
# Volume                   148694000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 58.125
# square_open                    844
# Name: 15, dtype: object
# Date           2015-09-17 00:00:00
# Open                     28.915001
# High                     29.122499
# Low                          28.43
# Close                        28.48
# Adj Close                26.004856
# Volume                   256450400
# Name                        Gaétan
# Surname                    Chardon
# double_open              57.830002
# square_open                    836
# Name: 16, dtype: object
# Date           2015-09-18 00:00:00
# Open                       28.0525
# High                     28.575001
# Low                      27.967501
# Close                    28.362499
# Adj Close                25.897564
# Volume                   297141200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.105
# square_open                    786
# Name: 17, dtype: object
# Date           2015-09-21 00:00:00
# Open                       28.4175
# High                     28.842501
# Low                      28.415001
# Close                      28.8025
# Adj Close                26.299326
# Volume                   200888000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.835
# square_open                    807
# Name: 18, dtype: object
# Date           2015-09-22 00:00:00
# Open                     28.344999
# High                        28.545
# Low                      28.129999
# Close                        28.35
# Adj Close                25.886154
# Volume                   201384800
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.689998
# square_open                    803
# Name: 19, dtype: object
# Date           2015-09-23 00:00:00
# Open                     28.407499
# High                         28.68
# Low                      28.325001
# Close                        28.58
# Adj Close                26.096163
# Volume                   143026800
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.814998
# square_open                    806
# Name: 20, dtype: object
# Date           2015-09-24 00:00:00
# Open                       28.3125
# High                        28.875
# Low                      28.092501
# Close                        28.75
# Adj Close                26.251394
# Volume                   200878000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.625
# square_open                    801
# Name: 21, dtype: object
# Date           2015-09-25 00:00:00
# Open                     29.110001
# High                     29.172501
# Low                      28.504999
# Close                      28.6775
# Adj Close                 26.18519
# Volume                   224607600
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.220002
# square_open                    847
# Name: 22, dtype: object
# Date           2015-09-28 00:00:00
# Open                       28.4625
# High                       28.6425
# Low                      28.110001
# Close                    28.110001
# Adj Close                25.667015
# Volume                   208436000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.925
# square_open                    810
# Name: 23, dtype: object
# Date           2015-09-29 00:00:00
# Open                       28.2075
# High                     28.377501
# Low                         26.965
# Close                    27.264999
# Adj Close                24.895449
# Volume                   293461600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 56.415
# square_open                    795
# Name: 24, dtype: object
# Date           2015-09-30 00:00:00
# Open                       27.5425
# High                        27.885
# Low                      27.182501
# Close                    27.575001
# Adj Close                25.178503
# Volume                   265892000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.085
# square_open                    758
# Name: 25, dtype: object
# Date           2015-10-01 00:00:00
# Open                       27.2675
# High                     27.405001
# Low                      26.827499
# Close                       27.395
# Adj Close                25.014153
# Volume                   255716400
# Name                        Gaétan
# Surname                    Chardon
# double_open                 54.535
# square_open                    743
# Name: 26, dtype: object
# Date           2015-10-02 00:00:00
# Open                     27.002501
# High                     27.752501
# Low                      26.887501
# Close                    27.594999
# Adj Close                25.196772
# Volume                   232079200
# Name                        Gaétan
# Surname                    Chardon
# double_open              54.005002
# square_open                    729
# Name: 27, dtype: object
# Date           2015-10-05 00:00:00
# Open                     27.469999
# High                     27.842501
# Low                        27.2675
# Close                       27.695
# Adj Close                25.288078
# Volume                   208258800
# Name                        Gaétan
# Surname                    Chardon
# double_open              54.939998
# square_open                    754
# Name: 28, dtype: object
# Date           2015-10-06 00:00:00
# Open                     27.657499
# High                     27.934999
# Low                      27.442499
# Close                    27.827499
# Adj Close                25.409065
# Volume                   192787200
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.314998
# square_open                    764
# Name: 29, dtype: object
# Date           2015-10-07 00:00:00
# Open                     27.934999
# High                     27.942499
# Low                      27.352501
# Close                       27.695
# Adj Close                25.288078
# Volume                   187062400
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.869998
# square_open                    780
# Name: 30, dtype: object
# Date           2015-10-08 00:00:00
# Open                     27.547501
# High                     27.547501
# Low                        27.0525
# Close                       27.375
# Adj Close                 24.99589
# Volume                   247918400
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.095002
# square_open                    758
# Name: 31, dtype: object
# Date           2015-10-09 00:00:00
# Open                          27.5
# High                         28.07
# Low                      27.372499
# Close                    28.030001
# Adj Close                25.593964
# Volume                   211064400
# Name                        Gaétan
# Surname                    Chardon
# double_open                   55.0
# square_open                    756
# Name: 32, dtype: object
# Date           2015-10-12 00:00:00
# Open                     28.182501
# High                       28.1875
# Low                      27.860001
# Close                         27.9
# Adj Close                 25.47526
# Volume                   121868800
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.365002
# square_open                    794
# Name: 33, dtype: object
# Date           2015-10-13 00:00:00
# Open                        27.705
# High                     28.112499
# Low                          27.67
# Close                      27.9475
# Adj Close                25.518633
# Volume                   132197200
# Name                        Gaétan
# Surname                    Chardon
# double_open                  55.41
# square_open                    767
# Name: 34, dtype: object
# Date           2015-10-14 00:00:00
# Open                       27.8225
# High                     27.879999
# Low                      27.389999
# Close                      27.5525
# Adj Close                25.157961
# Volume                   177849600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.645
# square_open                    774
# Name: 35, dtype: object
# Date           2015-10-15 00:00:00
# Open                       27.7325
# High                        28.025
# Low                      27.622499
# Close                       27.965
# Adj Close                25.534609
# Volume                   150694000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.465
# square_open                    769
# Name: 36, dtype: object
# Date           2015-10-16 00:00:00
# Open                        27.945
# High                          28.0
# Low                        27.6325
# Close                        27.76
# Adj Close                25.347437
# Volume                   156930400
# Name                        Gaétan
# Surname                    Chardon
# double_open                  55.89
# square_open                    780
# Name: 37, dtype: object
# Date           2015-10-19 00:00:00
# Open                     27.700001
# High                       27.9375
# Low                        27.5275
# Close                    27.932501
# Adj Close                25.504932
# Volume                   119036800
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.400002
# square_open                    767
# Name: 38, dtype: object
# Date           2015-10-20 00:00:00
# Open                     27.834999
# High                       28.5425
# Low                         27.705
# Close                    28.442499
# Adj Close                25.970615
# Volume                   195871200
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.669998
# square_open                    774
# Name: 39, dtype: object
# Date           2015-10-21 00:00:00
# Open                          28.5
# High                        28.895
# Low                      28.424999
# Close                    28.440001
# Adj Close                25.968327
# Volume                   167180800
# Name                        Gaétan
# Surname                    Chardon
# double_open                   57.0
# square_open                    812
# Name: 40, dtype: object
# Date           2015-10-22 00:00:00
# Open                       28.5825
# High                        28.875
# Low                         28.525
# Close                       28.875
# Adj Close                26.365528
# Volume                   166616400
# Name                        Gaétan
# Surname                    Chardon
# double_open                 57.165
# square_open                    816
# Name: 41, dtype: object
# Date           2015-10-23 00:00:00
# Open                     29.174999
# High                     29.807501
# Low                        29.0825
# Close                        29.77
# Adj Close                27.182737
# Volume                   237467600
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.349998
# square_open                    851
# Name: 42, dtype: object
# Date           2015-10-26 00:00:00
# Open                         29.52
# High                     29.532499
# Low                          28.73
# Close                        28.82
# Adj Close                26.315304
# Volume                   265335200
# Name                        Gaétan
# Surname                    Chardon
# double_open                  59.04
# square_open                    871
# Name: 43, dtype: object
# Date           2015-10-27 00:00:00
# Open                         28.85
# High                        29.135
# Low                      28.497499
# Close                    28.637501
# Adj Close                26.148668
# Volume                   279537600
# Name                        Gaétan
# Surname                    Chardon
# double_open                   57.7
# square_open                    832
# Name: 44, dtype: object
# Date           2015-10-28 00:00:00
# Open                       29.2325
# High                     29.825001
# Low                      29.014999
# Close                    29.817499
# Adj Close                 27.22611
# Volume                   342205600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 58.465
# square_open                    854
# Name: 45, dtype: object
# Date           2015-10-29 00:00:00
# Open                     29.674999
# High                     30.172501
# Low                      29.567499
# Close                      30.1325
# Adj Close                27.513735
# Volume                   204909200
# Name                        Gaétan
# Surname                    Chardon
# double_open              59.349998
# square_open                    880
# Name: 46, dtype: object
# Date           2015-10-30 00:00:00
# Open                     30.247499
# High                        30.305
# Low                      29.862499
# Close                       29.875
# Adj Close                27.278614
# Volume                   197461200
# Name                        Gaétan
# Surname                    Chardon
# double_open              60.494998
# square_open                    914
# Name: 47, dtype: object
# Date           2015-11-02 00:00:00
# Open                     30.200001
# High                         30.34
# Low                        29.9025
# Close                       30.295
# Adj Close                27.662121
# Volume                   128813200
# Name                        Gaétan
# Surname                    Chardon
# double_open              60.400002
# square_open                    912
# Name: 48, dtype: object
# Date           2015-11-03 00:00:00
# Open                       30.1975
# High                     30.872499
# Low                      30.174999
# Close                      30.6425
# Adj Close                27.979418
# Volume                   182076000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 60.395
# square_open                    911
# Name: 49, dtype: object
# Date           2015-11-04 00:00:00
# Open                     30.782499
# High                        30.955
# Low                      30.405001
# Close                         30.5
# Adj Close                27.849297
# Volume                   179544400
# Name                        Gaétan
# Surname                    Chardon
# double_open              61.564998
# square_open                    947
# Name: 50, dtype: object
# Date           2015-11-05 00:00:00
# Open                       30.4625
# High                     30.672501
# Low                         30.045
# Close                        30.23
# Adj Close                27.720922
# Volume                   158210800
# Name                        Gaétan
# Surname                    Chardon
# double_open                 60.925
# square_open                    927
# Name: 51, dtype: object
# Date           2015-11-06 00:00:00
# Open                       30.2775
# High                     30.452499
# Low                      30.155001
# Close                    30.264999
# Adj Close                27.753016
# Volume                   132169200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 60.555
# square_open                    916
# Name: 52, dtype: object
# Date           2015-11-09 00:00:00
# Open                         30.24
# High                     30.452499
# Low                      30.012501
# Close                      30.1425
# Adj Close                27.640682
# Volume                   135485600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  60.48
# square_open                    914
# Name: 53, dtype: object
# Date           2015-11-10 00:00:00
# Open                        29.225
# High                       29.5175
# Low                      29.014999
# Close                    29.192499
# Adj Close                26.769529
# Volume                   236511600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  58.45
# square_open                    854
# Name: 54, dtype: object
# Date           2015-11-11 00:00:00
# Open                     29.092501
# High                        29.355
# Low                        28.8025
# Close                      29.0275
# Adj Close                26.618229
# Volume                   180872000
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.185002
# square_open                    846
# Name: 55, dtype: object
# Date           2015-11-12 00:00:00
# Open                     29.065001
# High                        29.205
# Low                        28.9125
# Close                        28.93
# Adj Close                26.528822
# Volume                   130102400
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.130002
# square_open                    844
# Name: 56, dtype: object
# Date           2015-11-13 00:00:00
# Open                     28.799999
# High                       28.8925
# Low                      28.067499
# Close                    28.084999
# Adj Close                 25.75395
# Volume                   183249600
# Name                        Gaétan
# Surname                    Chardon
# double_open              57.599998
# square_open                    829
# Name: 57, dtype: object
# Date           2015-11-16 00:00:00
# Open                     27.844999
# High                     28.559999
# Low                          27.75
# Close                       28.545
# Adj Close                26.175776
# Volume                   152426800
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.689998
# square_open                    775
# Name: 58, dtype: object
# Date           2015-11-17 00:00:00
# Open                         28.73
# High                     28.762501
# Low                          28.33
# Close                    28.422501
# Adj Close                26.063444
# Volume                   110467600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  57.46
# square_open                    825
# Name: 59, dtype: object
# Date           2015-11-18 00:00:00
# Open                     28.940001
# High                     29.372499
# Low                         28.875
# Close                      29.3225
# Adj Close                26.888742
# Volume                   186698800
# Name                        Gaétan
# Surname                    Chardon
# double_open              57.880002
# square_open                    837
# Name: 60, dtype: object
# Date           2015-11-19 00:00:00
# Open                         29.41
# High                       29.9375
# Low                      29.190001
# Close                       29.695
# Adj Close                27.230324
# Volume                   173183200
# Name                        Gaétan
# Surname                    Chardon
# double_open                  58.82
# square_open                    864
# Name: 61, dtype: object
# Date           2015-11-20 00:00:00
# Open                     29.799999
# High                         29.98
# Low                        29.7125
# Close                    29.825001
# Adj Close                27.349535
# Volume                   137148400
# Name                        Gaétan
# Surname                    Chardon
# double_open              59.599998
# square_open                    888
# Name: 62, dtype: object
# Date           2015-11-23 00:00:00
# Open                     29.817499
# High                     29.932501
# Low                      29.334999
# Close                      29.4375
# Adj Close                26.994192
# Volume                   129930000
# Name                        Gaétan
# Surname                    Chardon
# double_open              59.634998
# square_open                    889
# Name: 63, dtype: object
# Date           2015-11-24 00:00:00
# Open                       29.3325
# High                       29.8375
# Low                      29.280001
# Close                    29.719999
# Adj Close                27.253248
# Volume                   171212800
# Name                        Gaétan
# Surname                    Chardon
# double_open                 58.665
# square_open                    860
# Name: 64, dtype: object
# Date           2015-11-25 00:00:00
# Open                       29.8025
# High                     29.807501
# Low                          29.48
# Close                      29.5075
# Adj Close                27.058388
# Volume                    85553200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 59.605
# square_open                    888
# Name: 65, dtype: object
# Date           2015-11-27 00:00:00
# Open                       29.5725
# High                     29.602501
# Low                           29.4
# Close                    29.452499
# Adj Close                 27.00795
# Volume                    52185600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 59.145
# square_open                    874
# Name: 66, dtype: object
# Date           2015-11-30 00:00:00
# Open                     29.497499
# High                     29.852501
# Low                        29.4375
# Close                    29.575001
# Adj Close                27.120283
# Volume                   156721200
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.994998
# square_open                    870
# Name: 67, dtype: object
# Date           2015-12-01 00:00:00
# Open                       29.6875
# High                     29.702499
# Low                         29.215
# Close                    29.334999
# Adj Close                  26.9002
# Volume                   139409600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 59.375
# square_open                    881
# Name: 68, dtype: object
# Date           2015-12-02 00:00:00
# Open                     29.334999
# High                       29.5275
# Low                          29.02
# Close                        29.07
# Adj Close                  26.6572
# Volume                   133546400
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.669998
# square_open                    860
# Name: 69, dtype: object
# Date           2015-12-03 00:00:00
# Open                     29.137501
# High                       29.1975
# Low                         28.555
# Close                    28.799999
# Adj Close                26.409611
# Volume                   166278000
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.275002
# square_open                    848
# Name: 70, dtype: object
# Date           2015-12-04 00:00:00
# Open                       28.8225
# High                       29.8125
# Low                        28.7775
# Close                      29.7575
# Adj Close                27.287638
# Volume                   231108000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 57.645
# square_open                    830
# Name: 71, dtype: object
# Date           2015-12-07 00:00:00
# Open                     29.745001
# High                        29.965
# Low                      29.452499
# Close                        29.57
# Adj Close                  27.1157
# Volume                   128336800
# Name                        Gaétan
# Surname                    Chardon
# double_open              59.490002
# square_open                    884
# Name: 72, dtype: object
# Date           2015-12-08 00:00:00
# Open                     29.379999
# High                         29.65
# Low                         29.215
# Close                    29.557501
# Adj Close                 27.10424
# Volume                   137238000
# Name                        Gaétan
# Surname                    Chardon
# double_open              58.759998
# square_open                    863
# Name: 73, dtype: object
# Date           2015-12-09 00:00:00
# Open                         29.41
# High                     29.422501
# Low                          28.77
# Close                    28.905001
# Adj Close                26.505894
# Volume                   185445600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  58.82
# square_open                    864
# Name: 74, dtype: object
# Date           2015-12-10 00:00:00
# Open                         29.01
# High                     29.235001
# Low                      28.877501
# Close                      29.0425
# Adj Close                26.631983
# Volume                   116850800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  58.02
# square_open                    841
# Name: 75, dtype: object
# Date           2015-12-11 00:00:00
# Open                     28.797501
# High                       28.8475
# Low                        28.2125
# Close                       28.295
# Adj Close                25.946526
# Volume                   187544800
# Name                        Gaétan
# Surname                    Chardon
# double_open              57.595002
# square_open                    829
# Name: 76, dtype: object
# Date           2015-12-14 00:00:00
# Open                        28.045
# High                         28.17
# Low                        27.4475
# Close                    28.120001
# Adj Close                25.786051
# Volume                   257274800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  56.09
# square_open                    786
# Name: 77, dtype: object
# Date           2015-12-15 00:00:00
# Open                     27.985001
# High                     28.200001
# Low                        27.5875
# Close                    27.622499
# Adj Close                 25.32984
# Volume                   213292400
# Name                        Gaétan
# Surname                    Chardon
# double_open              55.970002
# square_open                    783
# Name: 78, dtype: object
# Date           2015-12-16 00:00:00
# Open                       27.7675
# High                     27.997499
# Low                      27.200001
# Close                    27.834999
# Adj Close                  25.5247
# Volume                   224954000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 55.535
# square_open                    771
# Name: 79, dtype: object
# Date           2015-12-17 00:00:00
# Open                     28.004999
# High                       28.0625
# Low                      27.245001
# Close                    27.245001
# Adj Close                24.983675
# Volume                   179091200
# Name                        Gaétan
# Surname                    Chardon
# double_open              56.009998
# square_open                    784
# Name: 80, dtype: object
# Date           2015-12-18 00:00:00
# Open                     27.227501
# High                     27.379999
# Low                      26.452499
# Close                      26.5075
# Adj Close                24.307384
# Volume                   385813200
# Name                        Gaétan
# Surname                    Chardon
# double_open              54.455002
# square_open                    741
# Name: 81, dtype: object
# Date           2015-12-21 00:00:00
# Open                         26.82
# High                     26.842501
# Low                        26.3925
# Close                      26.8325
# Adj Close                24.605406
# Volume                   190362400
# Name                        Gaétan
# Surname                    Chardon
# double_open                  53.64
# square_open                    719
# Name: 82, dtype: object
# Date           2015-12-22 00:00:00
# Open                         26.85
# High                         26.93
# Low                      26.612499
# Close                    26.807501
# Adj Close                24.582485
# Volume                   131157600
# Name                        Gaétan
# Surname                    Chardon
# double_open                   53.7
# square_open                    720
# Name: 83, dtype: object
# Date           2015-12-23 00:00:00
# Open                     26.817499
# High                       27.2125
# Low                      26.799999
# Close                      27.1525
# Adj Close                24.898848
# Volume                   130629600
# Name                        Gaétan
# Surname                    Chardon
# double_open              53.634998
# square_open                    719
# Name: 84, dtype: object
# Date           2015-12-24 00:00:00
# Open                         27.25
# High                         27.25
# Low                      26.987499
# Close                      27.0075
# Adj Close                24.765888
# Volume                    54281600
# Name                        Gaétan
# Surname                    Chardon
# double_open                   54.5
# square_open                    742
# Name: 85, dtype: object
# Date           2015-12-28 00:00:00
# Open                     26.897499
# High                     26.922501
# Low                         26.545
# Close                       26.705
# Adj Close                24.488493
# Volume                   106816800
# Name                        Gaétan
# Surname                    Chardon
# double_open              53.794998
# square_open                    723
# Name: 86, dtype: object
# Date           2015-12-29 00:00:00
# Open                         26.74
# High                       27.3575
# Low                         26.715
# Close                    27.184999
# Adj Close                24.928652
# Volume                   123724800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  53.48
# square_open                    715
# Name: 87, dtype: object
# Date           2015-12-30 00:00:00
# Open                        27.145
# High                     27.174999
# Low                         26.795
# Close                        26.83
# Adj Close                24.603117
# Volume                   100855200
# Name                        Gaétan
# Surname                    Chardon
# double_open                  54.29
# square_open                    736
# Name: 88, dtype: object
# Date           2015-12-31 00:00:00
# Open                     26.752501
# High                       26.7575
# Low                         26.205
# Close                    26.315001
# Adj Close                24.130867
# Volume                   163649200
# Name                        Gaétan
# Surname                    Chardon
# double_open              53.505002
# square_open                    715
# Name: 89, dtype: object
# Date           2016-01-04 00:00:00
# Open                       25.6525
# High                     26.342501
# Low                           25.5
# Close                      26.3375
# Adj Close                24.151491
# Volume                   270597600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 51.305
# square_open                    658
# Name: 90, dtype: object
# Date           2016-01-05 00:00:00
# Open                       26.4375
# High                       26.4625
# Low                      25.602501
# Close                      25.6775
# Adj Close                23.546274
# Volume                   223164000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 52.875
# square_open                    698
# Name: 91, dtype: object
# Date           2016-01-06 00:00:00
# Open                     25.139999
# High                     25.592501
# Low                      24.967501
# Close                    25.174999
# Adj Close                23.085487
# Volume                   273829600
# Name                        Gaétan
# Surname                    Chardon
# double_open              50.279998
# square_open                    632
# Name: 92, dtype: object
# Date           2016-01-07 00:00:00
# Open                         24.67
# High                     25.032499
# Low                        24.1075
# Close                    24.112499
# Adj Close                22.111174
# Volume                   324377600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  49.34
# square_open                    608
# Name: 93, dtype: object
# Date           2016-01-08 00:00:00
# Open                     24.637501
# High                       24.7775
# Low                      24.190001
# Close                        24.24
# Adj Close                22.228086
# Volume                   283192000
# Name                        Gaétan
# Surname                    Chardon
# double_open              49.275002
# square_open                    607
# Name: 94, dtype: object
# Date           2016-01-11 00:00:00
# Open                       24.7425
# High                     24.764999
# Low                      24.334999
# Close                      24.6325
# Adj Close                22.588009
# Volume                   198957600
# Name                        Gaétan
# Surname                    Chardon
# double_open                 49.485
# square_open                    612
# Name: 95, dtype: object
# Date           2016-01-12 00:00:00
# Open                     25.137501
# High                     25.172501
# Low                      24.709999
# Close                        24.99
# Adj Close                 22.91584
# Volume                   196616800
# Name                        Gaétan
# Surname                    Chardon
# double_open              50.275002
# square_open                    631
# Name: 96, dtype: object
# Date           2016-01-13 00:00:00
# Open                         25.08
# High                     25.297501
# Low                      24.325001
# Close                      24.3475
# Adj Close                22.326664
# Volume                   249758400
# Name                        Gaétan
# Surname                    Chardon
# double_open                  50.16
# square_open                    629
# Name: 97, dtype: object
# Date           2016-01-14 00:00:00
# Open                         24.49
# High                     25.120001
# Low                      23.934999
# Close                    24.879999
# Adj Close                22.814966
# Volume                   252680400
# Name                        Gaétan
# Surname                    Chardon
# double_open                  48.98
# square_open                    599
# Name: 98, dtype: object
# Date           2016-01-15 00:00:00
# Open                     24.049999
# High                       24.4275
# Low                          23.84
# Close                    24.282499
# Adj Close                22.267059
# Volume                   319335600
# Name                        Gaétan
# Surname                    Chardon
# double_open              48.099998
# square_open                    578
# Name: 99, dtype: object
# Date           2016-01-19 00:00:00
# Open                     24.602501
# High                       24.6625
# Low                         23.875
# Close                    24.165001
# Adj Close                22.159313
# Volume                   212350800
# Name                        Gaétan
# Surname                    Chardon
# double_open              49.205002
# square_open                    605
# Name: 100, dtype: object
# Date           2016-01-20 00:00:00
# Open                        23.775
# High                     24.547501
# Low                         23.355
# Close                      24.1975
# Adj Close                 22.18911
# Volume                   289337600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  47.55
# square_open                    565
# Name: 101, dtype: object
# Date           2016-01-21 00:00:00
# Open                     24.264999
# High                     24.469999
# Low                      23.735001
# Close                    24.075001
# Adj Close                22.076786
# Volume                   208646000
# Name                        Gaétan
# Surname                    Chardon
# double_open              48.529998
# square_open                    588
# Name: 102, dtype: object
# Date           2016-01-22 00:00:00
# Open                     24.657499
# High                        25.365
# Low                      24.592501
# Close                       25.355
# Adj Close                23.250544
# Volume                   263202000
# Name                        Gaétan
# Surname                    Chardon
# double_open              49.314998
# square_open                    607
# Name: 103, dtype: object
# Date           2016-01-25 00:00:00
# Open                     25.379999
# High                       25.3825
# Low                        24.8025
# Close                    24.860001
# Adj Close                22.796629
# Volume                   207178000
# Name                        Gaétan
# Surname                    Chardon
# double_open              50.759998
# square_open                    644
# Name: 104, dtype: object
# Date           2016-01-26 00:00:00
# Open                       24.9825
# High                     25.219999
# Low                        24.5175
# Close                    24.997499
# Adj Close                22.922716
# Volume                   300308000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 49.965
# square_open                    624
# Name: 105, dtype: object
# Date           2016-01-27 00:00:00
# Open                         24.01
# High                     24.157499
# Low                      23.334999
# Close                       23.355
# Adj Close                 21.41654
# Volume                   533478800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  48.02
# square_open                    576
# Name: 106, dtype: object
# Date           2016-01-28 00:00:00
# Open                       23.4475
# High                     23.629999
# Low                        23.0975
# Close                    23.522499
# Adj Close                21.570145
# Volume                   222715200
# Name                        Gaétan
# Surname                    Chardon
# double_open                 46.895
# square_open                    549
# Name: 107, dtype: object
# Date           2016-01-29 00:00:00
# Open                       23.6975
# High                     24.334999
# Low                        23.5875
# Close                    24.334999
# Adj Close                22.315205
# Volume                   257666000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 47.395
# square_open                    561
# Name: 108, dtype: object
# Date           2016-02-01 00:00:00
# Open                       24.1175
# High                       24.1775
# Low                          23.85
# Close                      24.1075
# Adj Close                22.106583
# Volume                   163774000
# Name                        Gaétan
# Surname                    Chardon
# double_open                 48.235
# square_open                    581
# Name: 109, dtype: object
# Date           2016-02-02 00:00:00
# Open                        23.855
# High                         24.01
# Low                          23.57
# Close                    23.620001
# Adj Close                 21.65955
# Volume                   149428800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  47.71
# square_open                    569
# Name: 110, dtype: object
# Date           2016-02-03 00:00:00
# Open                         23.75
# High                     24.209999
# Low                          23.52
# Close                      24.0875
# Adj Close                22.088245
# Volume                   183857200
# Name                        Gaétan
# Surname                    Chardon
# double_open                   47.5
# square_open                    564
# Name: 111, dtype: object
# Date           2016-02-04 00:00:00
# Open                        23.965
# High                       24.3325
# Low                      23.797501
# Close                        24.15
# Adj Close                22.265726
# Volume                   185886800
# Name                        Gaétan
# Surname                    Chardon
# double_open                  47.93
# square_open                    574
# Name: 112, dtype: object
# Date           2016-02-05 00:00:00
# Open                     24.129999
# High                         24.23
# Low                      23.422501
# Close                    23.504999
# Adj Close                21.671049
# Volume                   185672400
# Name                        Gaétan
# Surname                    Chardon
# double_open              48.259998
# square_open                    582
# Name: 113, dtype: object
# Date           2016-02-08 00:00:00
# Open                     23.282499
# High                     23.924999
# Low                          23.26
# Close                    23.752501
# Adj Close                21.899239
# Volume                   216085600
# Name                        Gaétan
# Surname                    Chardon
# double_open              46.564998
# square_open                    542
# Name: 114, dtype: object
# Date           2016-02-09 00:00:00
# Open                       23.5725
# High                     23.985001
# Low                        23.4825
# Close                    23.747499
# Adj Close                21.894634
# Volume                   177324800
# Name                        Gaétan
# Surname                    Chardon
# double_open                 47.145
# square_open                    555
# Name: 115, dtype: object
# Date           2016-02-10 00:00:00
# Open                         23.98
# High                       24.0875
# Low                         23.525
# Close                    23.567499
# Adj Close                21.728678
# Volume                   169374400
# Name                        Gaétan
# Surname                    Chardon
# double_open                  47.96
# square_open                    575
# Name: 116, dtype: object
# Date           2016-02-11 00:00:00
# Open                       23.4475
# High                         23.68
# Low                      23.147499
# ...
# Open                        137.25
# High                    138.369995
# Low                     133.770004
# Close                   136.720001
# Adj Close                136.53035
# Volume                    98964500
# Name                        Gaétan
# Surname                    Chardon
# double_open                  274.5
# square_open                  18837
# Name: 1724, dtype: object
# Date           2022-07-01 00:00:00
# Open                    136.039993
# High                    139.039993
# Low                     135.660004
# Close                   138.929993
# Adj Close               138.737274
# Volume                    71051600
# Name                        Gaétan
# Surname                    Chardon
# double_open             272.079986
# square_open                  18506
# Name: 1725, dtype: object
# Date           2022-07-05 00:00:00
# Open                    137.770004
# High                    141.610001
# Low                     136.929993
# Close                   141.559998
# Adj Close               141.363632
# Volume                    73353800
# Name                        Gaétan
# Surname                    Chardon
# double_open             275.540008
# square_open                  18980
# Name: 1726, dtype: object
# Date           2022-07-06 00:00:00
# Open                    141.350006
# High                    144.119995
# Low                     141.080002
# Close                   142.919998
# Adj Close               142.721756
# Volume                    74064300
# Name                        Gaétan
# Surname                    Chardon
# double_open             282.700012
# square_open                  19979
# Name: 1727, dtype: object
# Date           2022-07-07 00:00:00
# Open                    143.289993
# High                    146.550003
# Low                     143.279999
# Close                   146.350006
# Adj Close               146.147003
# Volume                    66253700
# Name                        Gaétan
# Surname                    Chardon
# double_open             286.579986
# square_open                  20532
# Name: 1728, dtype: object
# Date           2022-07-08 00:00:00
# Open                    145.259995
# High                    147.550003
# Low                          145.0
# Close                   147.039993
# Adj Close               146.836029
# Volume                    64547800
# Name                        Gaétan
# Surname                    Chardon
# double_open              290.51999
# square_open                  21100
# Name: 1729, dtype: object
# Date           2022-07-11 00:00:00
# Open                    145.669998
# High                    146.639999
# Low                     143.779999
# Close                   144.869995
# Adj Close               144.669037
# Volume                    63141600
# Name                        Gaétan
# Surname                    Chardon
# double_open             291.339996
# square_open                  21219
# Name: 1730, dtype: object
# Date           2022-07-12 00:00:00
# Open                    145.759995
# High                    148.449997
# Low                     145.050003
# Close                   145.860001
# Adj Close               145.657669
# Volume                    77588800
# Name                        Gaétan
# Surname                    Chardon
# double_open              291.51999
# square_open                  21245
# Name: 1731, dtype: object
# Date           2022-07-13 00:00:00
# Open                    142.990005
# High                    146.449997
# Low                     142.119995
# Close                   145.490005
# Adj Close               145.288193
# Volume                    71185600
# Name                        Gaétan
# Surname                    Chardon
# double_open              285.98001
# square_open                  20446
# Name: 1732, dtype: object
# Date           2022-07-14 00:00:00
# Open                    144.080002
# High                    148.949997
# Low                         143.25
# Close                   148.470001
# Adj Close               148.264053
# Volume                    78140700
# Name                        Gaétan
# Surname                    Chardon
# double_open             288.160004
# square_open                  20759
# Name: 1733, dtype: object
# Date           2022-07-15 00:00:00
# Open                    149.779999
# High                    150.860001
# Low                     148.199997
# Close                   150.169998
# Adj Close                 149.9617
# Volume                    76259900
# Name                        Gaétan
# Surname                    Chardon
# double_open             299.559998
# square_open                  22434
# Name: 1734, dtype: object
# Date           2022-07-18 00:00:00
# Open                    150.740005
# High                    151.570007
# Low                     146.699997
# Close                   147.070007
# Adj Close               146.865997
# Volume                    81420900
# Name                        Gaétan
# Surname                    Chardon
# double_open              301.48001
# square_open                  22722
# Name: 1735, dtype: object
# Date           2022-07-19 00:00:00
# Open                    147.919998
# High                    151.229996
# Low                     146.910004
# Close                        151.0
# Adj Close               150.790543
# Volume                    82982400
# Name                        Gaétan
# Surname                    Chardon
# double_open             295.839996
# square_open                  21880
# Name: 1736, dtype: object
# Date           2022-07-20 00:00:00
# Open                    151.119995
# High                    153.720001
# Low                     150.369995
# Close                   153.039993
# Adj Close               152.827713
# Volume                    64823400
# Name                        Gaétan
# Surname                    Chardon
# double_open              302.23999
# square_open                  22837
# Name: 1737, dtype: object
# Date           2022-07-21 00:00:00
# Open                         154.5
# High                    155.570007
# Low                     151.940002
# Close                   155.350006
# Adj Close               155.134521
# Volume                    65086600
# Name                        Gaétan
# Surname                    Chardon
# double_open                  309.0
# square_open                  23870
# Name: 1738, dtype: object
# Date           2022-07-22 00:00:00
# Open                    155.389999
# High                    156.279999
# Low                     153.410004
# Close                   154.089996
# Adj Close               153.876251
# Volume                    66675400
# Name                        Gaétan
# Surname                    Chardon
# double_open             310.779998
# square_open                  24146
# Name: 1739, dtype: object
# Date           2022-07-25 00:00:00
# Open                    154.009995
# High                    155.039993
# Low                     152.279999
# Close                   152.949997
# Adj Close               152.737839
# Volume                    53623900
# Name                        Gaétan
# Surname                    Chardon
# double_open              308.01999
# square_open                  23719
# Name: 1740, dtype: object
# Date           2022-07-26 00:00:00
# Open                    152.259995
# High                    153.089996
# Low                     150.800003
# Close                   151.600006
# Adj Close               151.389725
# Volume                    55138700
# Name                        Gaétan
# Surname                    Chardon
# double_open              304.51999
# square_open                  23183
# Name: 1741, dtype: object
# Date           2022-07-27 00:00:00
# Open                    152.580002
# High                    157.330002
# Low                     152.160004
# Close                   156.789993
# Adj Close                156.57251
# Volume                    78620700
# Name                        Gaétan
# Surname                    Chardon
# double_open             305.160004
# square_open                  23280
# Name: 1742, dtype: object
# Date           2022-07-28 00:00:00
# Open                    156.979996
# High                    157.639999
# Low                     154.410004
# Close                   157.350006
# Adj Close               157.131744
# Volume                    81378700
# Name                        Gaétan
# Surname                    Chardon
# double_open             313.959992
# square_open                  24642
# Name: 1743, dtype: object
# Date           2022-07-29 00:00:00
# Open                    161.240005
# High                    163.630005
# Low                          159.5
# Close                   162.509995
# Adj Close               162.284576
# Volume                   101689200
# Name                        Gaétan
# Surname                    Chardon
# double_open              322.48001
# square_open                  25998
# Name: 1744, dtype: object
# Date           2022-08-01 00:00:00
# Open                    161.009995
# High                    163.589996
# Low                     160.889999
# Close                   161.509995
# Adj Close               161.285965
# Volume                    67829400
# Name                        Gaétan
# Surname                    Chardon
# double_open              322.01999
# square_open                  25924
# Name: 1745, dtype: object
# Date           2022-08-02 00:00:00
# Open                    160.100006
# High                    162.410004
# Low                     159.630005
# Close                   160.009995
# Adj Close                159.78804
# Volume                    59907000
# Name                        Gaétan
# Surname                    Chardon
# double_open             320.200012
# square_open                  25632
# Name: 1746, dtype: object
# Date           2022-08-03 00:00:00
# Open                    160.839996
# High                    166.589996
# Low                         160.75
# Close                   166.130005
# Adj Close               165.899567
# Volume                    82507500
# Name                        Gaétan
# Surname                    Chardon
# double_open             321.679992
# square_open                  25869
# Name: 1747, dtype: object
# Date           2022-08-04 00:00:00
# Open                    166.009995
# High                    167.190002
# Low                     164.429993
# Close                   165.809998
# Adj Close               165.580002
# Volume                    55474100
# Name                        Gaétan
# Surname                    Chardon
# double_open              332.01999
# square_open                  27559
# Name: 1748, dtype: object
# Date           2022-08-05 00:00:00
# Open                    163.210007
# High                    165.850006
# Low                          163.0
# Close                   165.350006
# Adj Close               165.350006
# Volume                    56646600
# Name                        Gaétan
# Surname                    Chardon
# double_open             326.420014
# square_open                  26637
# Name: 1749, dtype: object
# Date           2022-08-08 00:00:00
# Open                    166.369995
# High                    167.809998
# Low                     164.199997
# Close                   164.869995
# Adj Close               164.869995
# Volume                    60276900
# Name                        Gaétan
# Surname                    Chardon
# double_open              332.73999
# square_open                  27678
# Name: 1750, dtype: object
# Date           2022-08-09 00:00:00
# Open                    164.020004
# High                    165.820007
# Low                         163.25
# Close                   164.919998
# Adj Close               164.919998
# Volume                    63135500
# Name                        Gaétan
# Surname                    Chardon
# double_open             328.040008
# square_open                  26902
# Name: 1751, dtype: object
# Date           2022-08-10 00:00:00
# Open                    167.679993
# High                    169.339996
# Low                     166.899994
# Close                   169.240005
# Adj Close               169.240005
# Volume                    70170500
# Name                        Gaétan
# Surname                    Chardon
# double_open             335.359986
# square_open                  28116
# Name: 1752, dtype: object
# Date           2022-08-11 00:00:00
# Open                    170.059998
# High                    170.990005
# Low                     168.190002
# Close                   168.490005
# Adj Close               168.490005
# Volume                    57149200
# Name                        Gaétan
# Surname                    Chardon
# double_open             340.119996
# square_open                  28920
# Name: 1753, dtype: object
# Date           2022-08-12 00:00:00
# Open                    169.820007
# High                    172.169998
# Low                     169.399994
# Close                   172.100006
# Adj Close               172.100006
# Volume                    67946400
# Name                        Gaétan
# Surname                    Chardon
# double_open             339.640014
# square_open                  28838
# Name: 1754, dtype: object
# Date           2022-08-15 00:00:00
# Open                    171.520004
# High                    173.389999
# Low                     171.350006
# Close                   173.190002
# Adj Close               173.190002
# Volume                    54091700
# Name                        Gaétan
# Surname                    Chardon
# double_open             343.040008
# square_open                  29419
# Name: 1755, dtype: object
# Date           2022-08-16 00:00:00
# Open                    172.779999
# High                    173.710007
# Low                     171.660004
# Close                   173.029999
# Adj Close               173.029999
# Volume                    56377100
# Name                        Gaétan
# Surname                    Chardon
# double_open             345.559998
# square_open                  29852
# Name: 1756, dtype: object
# Date           2022-08-17 00:00:00
# Open                    172.770004
# High                    176.149994
# Low                     172.570007
# Close                   174.550003
# Adj Close               174.550003
# Volume                    79542000
# Name                        Gaétan
# Surname                    Chardon
# double_open             345.540008
# square_open                  29849
# Name: 1757, dtype: object
# Date           2022-08-18 00:00:00
# Open                        173.75
# High                    174.899994
# Low                     173.119995
# Close                   174.149994
# Adj Close               174.149994
# Volume                    62290100
# Name                        Gaétan
# Surname                    Chardon
# double_open                  347.5
# square_open                  30189
# Name: 1758, dtype: object
# Date           2022-08-19 00:00:00
# Open                    173.029999
# High                    173.740005
# Low                     171.309998
# Close                   171.520004
# Adj Close               171.520004
# Volume                    70211500
# Name                        Gaétan
# Surname                    Chardon
# double_open             346.059998
# square_open                  29939
# Name: 1759, dtype: object
# Date           2022-08-22 00:00:00
# Open                    169.690002
# High                    169.860001
# Low                     167.139999
# Close                   167.570007
# Adj Close               167.570007
# Volume                    69026800
# Name                        Gaétan
# Surname                    Chardon
# double_open             339.380004
# square_open                  28794
# Name: 1760, dtype: object
# Date           2022-08-23 00:00:00
# Open                    167.080002
# High                    168.710007
# Low                     166.649994
# Close                   167.229996
# Adj Close               167.229996
# Volume                    54147100
# Name                        Gaétan
# Surname                    Chardon
# double_open             334.160004
# square_open                  27915
# Name: 1761, dtype: object
# Date           2022-08-24 00:00:00
# Open                    167.320007
# High                    168.110001
# Low                         166.25
# Close                   167.529999
# Adj Close               167.529999
# Volume                    53766800
# Name                        Gaétan
# Surname                    Chardon
# double_open             334.640014
# square_open                  27995
# Name: 1762, dtype: object

# %%
# Concatenate two dataframes
df1 = pd.DataFrame({'brand' : ['Coca', 'pepsi', 'Sprite', 'water'], 
                   'taste' : [5, 6, 9, 8],
                  'Sugar_content' : ['high', 'high', 'high', 'low']})
df2 = pd.DataFrame({'brand' : ['Coca', 'sdg', 'sdfe', 'wssdfer'], 
                   'taste' : [5, 6, 9, 8],
                  'Sugar_content' : ['high', 'high', 'high', 'low']})
df = pd.concat([df1, df2])
# df = df.reset_index(drop = True)
print(df)
# Out:
#      brand  taste Sugar_content
# 0     Coca      5          high
# 1    pepsi      6          high
# 2   Sprite      9          high
# 3    water      8           low
# 0     Coca      5          high
# 1      sdg      6          high
# 2     sdfe      9          high
# 3  wssdfer      8           low

# %%
# Delete the duplicate drop_duplicates function (see doc)
df = df.drop_duplicates()
print(df)
# Out:
#      brand  taste Sugar_content
# 0     Coca      5          high
# 1    pepsi      6          high
# 2   Sprite      9          high
# 3    water      8           low
# 1      sdg      6          high
# 2     sdfe      9          high
# 3  wssdfer      8           low

# %% [markdown]
# # Save the Dataframe

# %%
#Save it to excel
writer = pd.ExcelWriter(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_3\df.xlsx")
df.to_excel(writer, 'DataFrame')
writer.save()

# %%
#SAve it to csv
df.to_csv(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_3\df.csv", index = False)
print(pd.read_csv(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_3\df.csv"))
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-08-25   27.777500   27.777500   25.875000   25.934999   23.681032
# 1     2015-08-26   26.772499   27.472500   26.262501   27.422501   25.039267
# 2     2015-08-27   28.057501   28.309999   27.504999   28.230000   25.776581
# 3     2015-08-28   28.042500   28.327499   27.885000   28.322500   25.861042
# 4     2015-08-31   28.007500   28.632500   28.000000   28.190001   25.740063
# ...          ...         ...         ...         ...         ...         ...
# 1758  2022-08-18  173.750000  174.899994  173.119995  174.149994  174.149994
# 1759  2022-08-19  173.029999  173.740005  171.309998  171.520004  171.520004
# 1760  2022-08-22  169.690002  169.860001  167.139999  167.570007  167.570007
# 1761  2022-08-23  167.080002  168.710007  166.649994  167.229996  167.229996
# 1762  2022-08-24  167.320007  168.110001  166.250000  167.529999  167.529999
#
#          Volume
# 0     414406400
# 1     387098400
# 2     338464400
# 3     212657600
# 4     224917200
# ...         ...
# 1758   62290100
# 1759   70211500
# 1760   69026800
# 1761   54147100
# 1762   53766800
#
# [1763 rows x 7 columns]

# %%
# save it to json
df.to_json(r"D:\KBTU\2022-2023\Python Course\Course\Lecture\Lecture_3\df.json")

# %% [markdown]
# # Useful functions

# %%
# Getting info about the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1763 entries, 0 to 1762
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1763 non-null   datetime64[ns]
#  1   Open       1763 non-null   float64
#  2   High       1763 non-null   float64
#  3   Low        1763 non-null   float64
#  4   Close      1763 non-null   float64
#  5   Adj Close  1763 non-null   float64
#  6   Volume     1763 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 96.5 KB
# None

# %%
# Getting shapes of dataframe
print(df.shape)
# Out:
# (1763, 7)

# %%
# description of the dataframe
print(df.describe())
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1763.000000  1763.000000  1763.000000  1763.000000  1763.000000
# mean     73.145370    73.976154    72.362687    73.209046    71.725095
# std      47.930031    48.557681    47.330258    47.972945    48.449597
# min      22.500000    22.917500    22.367500    22.584999    20.949606
# 25%      36.377500    36.701250    36.123750    36.456251    34.464023
# 50%      49.904999    50.349998    49.544998    50.005001    48.601536
# 75%     120.500000   122.375000   119.080002   120.919998   119.526416
# max     182.630005   182.940002   179.119995   182.009995   181.259918
#
#              Volume
# count  1.763000e+03
# mean   1.264585e+08
# std    6.095225e+07
# min    4.100000e+07
# 25%    8.575620e+07
# 50%    1.094008e+08
# 75%    1.479908e+08
# max    5.334788e+08

# %%
# Count similar values (.value_counts() method)
print(df.value_counts('Open'))
# Out:
# Open
# 127.820000    3
# 24.000000     3
# 39.375000     3
# 144.029999    2
# 44.325001     2
#              ..
# 41.740002     1
# 41.717499     1
# 41.707500     1
# 41.660000     1
# 182.630005    1
# Length: 1691, dtype: int64

# %%
# get correlation
print(df.corr())
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999848  0.999799  0.999592   0.999570 -0.302755
# High       0.999848  1.000000  0.999764  0.999799   0.999785 -0.298205
# Low        0.999799  0.999764  1.000000  0.999807   0.999784 -0.309084
# Close      0.999592  0.999799  0.999807  1.000000   0.999979 -0.304046
# Adj Close  0.999570  0.999785  0.999784  0.999979   1.000000 -0.304374
# Volume    -0.302755 -0.298205 -0.309084 -0.304046  -0.304374  1.000000

# %%
# Quick plotting
#pip install matplotlib
df.plot(x = 'Date', y = 'Open')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#YOUR TURN 
#Plot the evolution of volume exchanged through the time of your csv file (10 minutes) 17:40
